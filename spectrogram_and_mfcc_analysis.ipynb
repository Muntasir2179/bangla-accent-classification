# %% [markdown]
# <a href="https://colab.research.google.com/github/Muntasir2179/bangla-accent-classification/blob/data-analysis/spectrogram_and_mfcc_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this colab notebook we will be trying to convert neumerical audio data into a `spectrogram` and `MFCC` image representation of our accents audio files.
#
# 🧮 Purpose: We are trying to learn.....
#
# * How every audio data is different.
# * Which `patterns` thay follow.
# * Asses our future `modeling` steps.
#
# 🧮 Why we are considering this way....
#
# * The main reason behind it is to `analyze the changes in spectrogram` for various audio files.
# * `The next model we ware planning to train was CNN`. This model is optimized in detecting patterns in images data.
# * That's the reason we want to train CNN in this way, `for that we need to represent our audio data in spectrogram and mfcc`.

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Spectrogram Analysis of audio

# %%
# creating function to generate spectorgram of audio file
def generate_spectrogram(audio_file_path, title):
  # loading the audio file with librosa
  data, sample_rate = librosa.load(audio_file_path)

  # generating spectrogram
  spec = librosa.feature.melspectrogram(y=data, sr=sample_rate)
  spec_db = librosa.power_to_db(spec, ref=np.max)

  # Display the original spectrogram without axes
  plt.figure(figsize=(8, 4))
  librosa.display.specshow(spec_db, sr=sample_rate, x_axis=None, y_axis=None)
  plt.title(title)
  plt.tight_layout()
  plt.show()

# %%
[
    generate_spectrogram('/content/drive/MyDrive/Datasets/bogura_audio_01.wav', 'Bogura Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/barishal_audio_01.wav', 'Barishal Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/pabna_audio_01.wav', 'Pabna Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/noakhali_audio_01.wav', 'Noakhali Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/chottgram_audio_01.wav', 'Chottogram Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/rajshahi_audio_01.wav', 'Rajshahi Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/puran_dhaka_audio_01.wav', 'Puran Dhaka Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/sylhet_audio_01.wav', 'Syhet Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/shatkhira_audio_01.wav', 'Shatkhira Audio'),
    generate_spectrogram('/content/drive/MyDrive/Datasets/maymenshing_audio_01.wav', 'Maymenshing Audio'),
]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ## MFCC Analysis

# %%
# function to display mfcc
def display_mfcc(audio_file_path, title):
  # Load the audio file using Librosa
  y, sr = librosa.load(audio_file_path)

  # Calculate MFCCs
  mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

  # Display the MFCC plot
  plt.figure(figsize=(8, 5))
  librosa.display.specshow(mfccs, x_axis=None)
  plt.title(title)
  plt.tight_layout()
  plt.show()

# %%
[
    display_mfcc('/content/drive/MyDrive/Datasets/bogura_audio_01.wav', 'Bogura Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/barishal_audio_01.wav', 'Barishal Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/pabna_audio_01.wav', 'Pabna Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/noakhali_audio_01.wav', 'Noakhali Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/chottgram_audio_01.wav', 'Chottogram Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/rajshahi_audio_01.wav', 'Rajshahi Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/puran_dhaka_audio_01.wav', 'Puran Dhaka Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/sylhet_audio_01.wav', 'Syhet Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/shatkhira_audio_01.wav', 'Shatkhira Audio'),
    display_mfcc('/content/drive/MyDrive/Datasets/maymenshing_audio_01.wav', 'Maymenshing Audio'),
]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# # 📖Result of this analysis:
#
# We have successfully generated spectrogram and mfcc and we have come to a conclusion that `spectrogram` is more appropriate in visualizing `patterns` in the audio data.
#
# 🔑Decision:
#
# We have decided to use spectrogram image to train our CNN model.
